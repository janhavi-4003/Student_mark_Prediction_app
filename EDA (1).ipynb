# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# Load the cleaned dataset
ds = pd.read_csv('new_cleanesd_data.csv')
ds
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc  LunchType  \
# 0               0  female     group B   bachelor's degree          1
# 1               1  female     group C        some college          1
# 2               2  female     group B     master's degree          1
# 3               3    male     group A  associate's degree          0
# 4               4    male     group C        some college          1
# ...           ...     ...         ...                 ...        ...
# 30636       30636    male     group C    some high school          1
# 30637       30637    male     group E  associate's degree          0
# 30638       30638    male     group C        some college          1
# 30639       30639    male     group A    some high school          0
# 30640       30640  female     group D  associate's degree          1
#
#         TestPrep  MathScore  ReadingScore  WritingScore
# 0           none         72            72            74
# ...

# %% [markdown]
# # Frequency Distriubution (Barplots)

# %%
# Count plots
plt.figure(figsize=(15,5))
for i, col in enumerate(['Gender', 'EthnicGroup', 'ParentEduc', 'TestPrep']):
    plt.subplot(1, 4, i+1)
    sns.countplot(x=ds[col])
    plt.xticks(rotation=45)
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Distribution of Scores(Histograms)

# %%
ds[['MathScore', 'ReadingScore', 'WritingScore']].hist(bins=30, figsize=(10,6))
plt.suptitle("Score Distributions")
plt.show()

# %% [markdown]
# # Boxplots to Detect Outliers

# %%
plt.figure(figsize=(12,4))
for i, col in enumerate(['MathScore', 'ReadingScore', 'WritingScore']):
    plt.subplot(1, 3, i+1)
    sns.boxplot(y=ds[col])
    plt.title(f"{col} - Boxplot")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Correlation Heatmap

# %%
sns.heatmap(ds[['MathScore', 'ReadingScore', 'WritingScore']].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation between scores")
plt.show()
